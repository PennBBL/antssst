# %% [markdown]
# Walk through of how to run XCP Engine for GRMPY_822831

# %%
import flywheel
import datetime
import pytz

fw = flywheel.Client('upenn.flywheel.io:22XIsvLOpUOg3ARsTa')
proj = fw.lookup('bbl/ALPRAZ_805556')
sessions = proj.sessions()
sessions = [fw.get(x.id) for x in sessions]
# Out:
# /Users/adebimpe/opt/miniconda3/lib/python3.7/site-packages/flywheel/flywheel.py:5931: UserWarning: Client version 10.4.1 does not match server version 11.0.1. Please update your client version!
#   warnings.warn('Client version {} does not match server version {}. Please update your client version!'.format(SDK_VERSION, release_version))
# WARNING:Flywheel:Use "pip install flywheel-sdk~=11.0.1" to install a compatible version for this server

# %% [markdown]
# Each session has an `fmriprep` analysis attached (if it was successful). How do we know they were successful?

# %%
sessions[0].analyses[0] # check analysis the firts
# Out:
# {'created': datetime.datetime(2020, 1, 10, 20, 27, 11, 784000, tzinfo=tzutc()),
#  'description': None,
#  'files': None,
#  'gear_info': {'category': 'analysis',
#                'id': '5da887766cbeb000b47d028e',
#                'name': 'fmriprep-hpc',
#                'version': '0.1.26_1.2.6-1'},
#  'id': '5e18de1f3a9694007a6c854f',
#  'info': None,
#  'inputs': [{'classification': {},
#              'created': datetime.datetime(2019, 3, 14, 20, 24, 57, 907000, tzinfo=tzutc()),
#              'hash': '',
#              'id': '2d2cea1f-9ed2-4f52-9d6c-8495d3ba4ce5',
#              'info': {},
#              'info_exists': None,
#              'mimetype': 'application/zip',
#              'modality': None,
#              'modified': datetime.datetime(2019, 3, 14, 20, 24, 57, 250000, tzinfo=tzutc()),
#              'name': 'ALPRAZ_805556.PROCESSING.zip',
#              'origin': {'id': 'harshakethineni@flywheel.io',
#                         'method': None,
#                         'name': None,
#                         'type': 'user',
#                         'via': None},
#              'replaced': None,
#              'size': 576084,
#              'tags': [],
#              'type': 'archive',
#              'zip_member_count': 97}],
#  'job': {'attempt': 1,
#          'compute_provider_id': '5d8ed960507ac10001ff63e4',
#          'config': {'config': {'FREESURFER_LICENSE': 'stauffer@upenn.edu\n'
#                                                      '20217\n'
#                                                      ' *CNJKge/MKN62\n'
#                                                      ' FShMG3atCAhWE\n',
#                                'anat_only': False,
#                                'aroma_melodic_dimensionality': 'None',
#                                'bold2t1w_dof': 9,
#                                'cifti_output': True,
#                                'fmap_bspline': False,
#                                'fmap_no_demean': False,
#                                'force_bbr': False,
#                                'force_no_bbr': False,
#                                'force_syn': False,
#                                'fs_no_reconall': False,
#                                'ignore': 'fieldmaps',
#                                'intermediate_files': '',
#                                'intermediate_folders': '',
#                                'longitudinal': False,
#                                'low_mem': False,
#                                'medial_surface_nan': False,
#                                'no_submm_recon': False,
#                                'output_space': 'template fsaverage5',
#                                'save_intermediate_work': False,
#                                'save_outputs': False,
#                                'sge-cpu': '8',
#                                'sge-ram': '64G',
#                                'sge-short': False,
#                                'singularity-debug': False,
#                                'singularity-writable': False,
#                                'skull_strip_fixed_seed': False,
#                                'skull_strip_template': 'OASIS',
#                                'sloppy_mode': False,
#                                't2s_coreg': False,
#                                'template': 'MNI152NLin2009cAsym',
#                                'template_resampling_grid': 'native',
#                                'use_all_sessions': False,
#                                'use_aroma': False,
#                                'use_syn_sdc': False},
#                     'destination': {'id': '5e18de1f3a9694007a6c854f',
#                                     'type': 'analysis'},
#                     'inputs': {'freesurfer_license': {'base': 'file',
#                                                       'hierarchy': {'id': '5c8ab803f546b600306d7bdc',
#                                                                     'type': 'project'},
#                                                       'location': {'name': 'ALPRAZ_805556.PROCESSING.zip',
#                                                                    'path': '/flywheel/v0/input/freesurfer_license/ALPRAZ_805556.PROCESSING.zip'},
#                                                       'object': {'classification': {},
#                                                                  'measurements': [],
#                                                                  'mimetype': 'application/zip',
#                                                                  'modality': None,
#                                                                  'size': 576084,
#                                                                  'tags': [],
#                                                                  'type': 'archive'}}}},
#          'created': datetime.datetime(2020, 1, 10, 20, 27, 11, 987000, tzinfo=tzutc()),
#          'destination': {'id': '5e18de1f3a9694007a6c854f', 'type': 'analysis'},
#          'failure_reason': None,
#          'gear_id': '5da887766cbeb000b47d028e',
#          'gear_info': {'category': 'analysis',
#                        'id': None,
#                        'name': 'fmriprep-hpc',
#                        'version': '0.1.26_1.2.6-1'},
#          'group': None,
#          'id': '5e18de1f3a9694007a6c8550',
#          'inputs': {'freesurfer_license': {'id': '5c8ab803f546b600306d7bdc',
#                                            'name': 'ALPRAZ_805556.PROCESSING.zip',
#                                            'type': 'project'}},
#          'label': '',
#          'modified': datetime.datetime(2020, 1, 10, 20, 28, 4, 294000, tzinfo=tzutc()),
#          'origin': {'id': 'larsenb@upenn.edu', 'type': 'user'},
#          'previous_job_id': None,
#          'profile': {'elapsed_time_ms': None,
#                      'executor': None,
#                      'preparation_time_ms': None,
#                      'total_input_files': 1,
#                      'total_input_size_bytes': 576084,
#                      'total_output_files': None,
#                      'total_output_size_bytes': None,
#                      'total_time_ms': 50083,
#                      'upload_time_ms': None,
#                      'versions': {'core': '10.6.1'}},
#          'project': None,
#          'related_container_ids': ['5c8ab804f546b600306d7be4',
#                                    'bbl',
#                                    '5e18de1f3a9694007a6c854f',
#                                    '5c8ab803f546b600306d7bdc',
#                                    '5c8ab80bf546b6002f6d78e9'],
#          'request': {'inputs': [{'location': '/',
#                                  'type': 'docker',
#                                  'uri': 'docker.io/pennbbl/fmriprep_fw:0.1.26_1.2.6-1',
#                                  'vu': None},
#                                 {'location': '/flywheel/v0',
#                                  'type': 'scitran',
#                                  'uri': '/jobs/5e18de1f3a9694007a6c8550/config.json',
#                                  'vu': None},
#                                 {'location': '/flywheel/v0/input/freesurfer_license',
#                                  'type': 'scitran',
#                                  'uri': '/projects/5c8ab803f546b600306d7bdc/files/ALPRAZ_805556.PROCESSING.zip',
#                                  'vu': None}],
#                      'outputs': [{'location': '/flywheel/v0/output',
#                                   'type': 'scitran',
#                                   'uri': '/engine?level=analysis&id=5e18de1f3a9694007a6c854f&job=5e18de1f3a9694007a6c8550'}],
#                      'target': {'command': ['bash', '-c', './run'],
#                                 'dir': '/flywheel/v0',
#                                 'env': {'FW_CONFIG_ANAT_ONLY': 'false',
#                                         'FW_CONFIG_AROMA_MELODIC_DIMENSIONALITY': 'None',
#                                         'FW_CONFIG_BOLD2T1W_DOF': '9',
#                                         'FW_CONFIG_CIFTI_OUTPUT': 'true',
#                                         'FW_CONFIG_FMAP_BSPLINE': 'false',
#                                         'FW_CONFIG_FMAP_NO_DEMEAN': 'false',
#                                         'FW_CONFIG_FORCE_BBR': 'false',
#                                         'FW_CONFIG_FORCE_NO_BBR': 'false',
#                                         'FW_CONFIG_FORCE_SYN': 'false',
#                                         'FW_CONFIG_FREESURFER_LICENSE': 'stauffer@upenn.edu\n'
#                                                                         '20217\n'
#                                                                         ' '
#                                                                         '*CNJKge/MKN62\n'
#                                                                         ' '
#                                                                         'FShMG3atCAhWE\n',
#                                         'FW_CONFIG_FS_NO_RECONALL': 'false',
#                                         'FW_CONFIG_IGNORE': 'fieldmaps',
#                                         'FW_CONFIG_INTERMEDIATE_FILES': '',
#                                         'FW_CONFIG_INTERMEDIATE_FOLDERS': '',
#                                         'FW_CONFIG_LONGITUDINAL': 'false',
#                                         'FW_CONFIG_LOW_MEM': 'false',
#                                         'FW_CONFIG_MEDIAL_SURFACE_NAN': 'false',
#                                         'FW_CONFIG_NO_SUBMM_RECON': 'false',
#                                         'FW_CONFIG_OUTPUT_SPACE': 'template '
#                                                                   'fsaverage5',
#                                         'FW_CONFIG_SAVE_INTERMEDIATE_WORK': 'false',
#                                         'FW_CONFIG_SAVE_OUTPUTS': 'false',
#                                         'FW_CONFIG_SGECPU': '8',
#                                         'FW_CONFIG_SGERAM': '64G',
#                                         'FW_CONFIG_SGESHORT': 'false',
#                                         'FW_CONFIG_SINGULARITYDEBUG': 'false',
#                                         'FW_CONFIG_SINGULARITYWRITABLE': 'false',
#                                         'FW_CONFIG_SKULL_STRIP_FIXED_SEED': 'false',
#                                         'FW_CONFIG_SKULL_STRIP_TEMPLATE': 'OASIS',
#                                         'FW_CONFIG_SLOPPY_MODE': 'false',
#                                         'FW_CONFIG_T2S_COREG': 'false',
#                                         'FW_CONFIG_TEMPLATE': 'MNI152NLin2009cAsym',
#                                         'FW_CONFIG_TEMPLATE_RESAMPLING_GRID': 'native',
#                                         'FW_CONFIG_USE_ALL_SESSIONS': 'false',
#                                         'FW_CONFIG_USE_AROMA': 'false',
#                                         'FW_CONFIG_USE_SYN_SDC': 'false',
#                                         'PATH': '/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin'}}},
#          'retried': None,
#          'saved_files': [],
#          'state': 'cancelled',
#          'tags': ['analysis', 'fmriprep-hpc'],
#          'transitions': {'cancelled': datetime.datetime(2020, 1, 10, 20, 28, 4, 294000, tzinfo=tzutc()),
#                          'complete': None,
#                          'failed': None,
#                          'running': datetime.datetime(2020, 1, 10, 20, 27, 14, 211000, tzinfo=tzutc())}},
#  'label': 'fmriprep_SDK_002258_2020-01-10_15:27',
#  'modified': datetime.datetime(2020, 1, 10, 20, 27, 12, 193000, tzinfo=tzutc()),
#  'notes': None,
#  'parent': {'id': '5c8ab80bf546b6002f6d78e9', 'type': 'session'},
#  'parents': {'acquisition': None,
#              'analysis': None,
#              'group': 'bbl',
#              'project': '5c8ab803f546b600306d7bdc',
#              'session': '5c8ab80bf546b6002f6d78e9',
#              'subject': '5c8ab804f546b600306d7be4'},
#  'revision': 2,
#  'tags': None}

# %%
sessions[4].files[2].name # check task name for subject 5
# Out:
# '02204_task.zip'

# %% [markdown]
# Analyses have attributes such as `state` and `info`:

# %%
[(x.gear_info, x.job.state) for x in sessions[0].analyses] # check fmriprep
# Out:
# [({'category': 'analysis',
#    'id': '5da887766cbeb000b47d028e',
#    'name': 'fmriprep-hpc',
#    'version': '0.1.26_1.2.6-1'}, 'cancelled'), ({'category': 'analysis',
#    'id': '5da887766cbeb000b47d028e',
#    'name': 'fmriprep-hpc',
#    'version': '0.1.26_1.2.6-1'}, 'failed'), ({'category': 'analysis',
#    'id': '5da887766cbeb000b47d028e',
#    'name': 'fmriprep-hpc',
#    'version': '0.1.26_1.2.6-1'}, 'failed'), ({'category': 'analysis',
#    'id': '5da887766cbeb000b47d028e',
#    'name': 'fmriprep-hpc',
#    'version': '0.1.26_1.2.6-1'}, 'cancelled'), ({'category': 'analysis',
#    'id': '5da886fa6cbeb000b47d0200',
#    'name': 'fmriprep',
#    'version': '0.1.26_1.2.6-1'}, 'complete'), ({'category': 'analysis',
#    'id': '5e0ea8a73a9694007a68028a',
#    'name': 'fmriprep-fwheudiconv',
#    'version': '0.2.2_1.5.2'}, 'complete'), ({'category': 'analysis',
#    'id': '5da887766cbeb000b47d028e',
#    'name': 'fmriprep-hpc',
#    'version': '0.1.26_1.2.6-1'}, 'complete'), ({'category': 'analysis',
#    'id': '5e3c2b176dea317b222a7404',
#    'name': 'xcpengine-fw',
#    'version': '1.0641'}, 'complete'), ({'category': 'analysis',
#    'id': '5e3c2b176dea317b222a7404',
#    'name': 'xcpengine-fw',
#    'version': '1.0641'}, 'complete'), ({'category': 'analysis',
#    'id': '5e769beb7204d510e7cfcf81',
#    'name': 'xcpengine-fw',
#    'version': '0.0.1_1.00'}, 'cancelled')]

# %% [markdown]
# We write a function that loops through the analyses of a session, checks if `fmriprep` ran successfully, and returns the most recent successful `fmriprep` analysis.

# %%
def get_latest_fmriprep(session):
    
    if session.analyses:
        
        timezone = pytz.timezone("UTC")
        init_date = datetime.datetime(2018, 1, 1)
        latest_date = timezone.localize(init_date)

        latest_run = None

        for i in session.analyses:
            gear_name = i.gear_info['name']
            state = i.job.state
            date = i.created
            if 'fmriprep' in gear_name and date > latest_date and state =='complete':
                latest_date = date
                latest_run = i
        
        if latest_run is not None:
            fmriprep_out = [x for x in latest_run.files if 'fmriprep' in x.name][0]
            fmriprep_out
            return(fmriprep_out)

        else:
            return None

    else:
        return None

# %%
latest_fmriprep = get_latest_fmriprep(sessions[0])
latest_fmriprep
# Out:
# {'classification': {},
#  'created': datetime.datetime(2020, 1, 31, 0, 48, 9, 919000, tzinfo=tzutc()),
#  'hash': 'v0-sha384-8d21ef7eb30379db741f17eff5a3ecf545f31cf1a346d8867220e358a6fa6d2eaf0e569f8ebe8f1229a16c884fadfd0f',
#  'id': '506d460a-7204-40b4-b213-0a6c8d1fc330',
#  'info': {},
#  'info_exists': None,
#  'mimetype': 'application/zip',
#  'modality': None,
#  'modified': datetime.datetime(2020, 1, 31, 0, 48, 9, 919000, tzinfo=tzutc()),
#  'name': 'fmriprep_sub-014665_5e32fccf6dea3102562a7432.zip',
#  'origin': {'id': '5e32fccf6dea3102562a7433',
#             'method': None,
#             'name': None,
#             'type': 'job',
#             'via': None},
#  'replaced': None,
#  'size': 1393564803,
#  'tags': [],
#  'type': 'archive',
#  'zip_member_count': None}

# %%
#get task file 
def get_taskfile(session):
    for i in range(len(session.files)):
        if session.files[i].name.endswith('task.zip'):
            taskfile=session.files[i]
        else:
            taskfile=None
    return taskfile

# %%
d=get_taskfile(sessions[7])
d
# Out:
# {'classification': {},
#  'created': datetime.datetime(2020, 2, 6, 15, 32, 9, 243000, tzinfo=tzutc()),
#  'hash': 'v0-sha384-ec45f3bf56cdbfbb88e1a4d7da47ea50888dc9264686b3c9bef84f23f989d657ed009149429c5527828df8beee602a6a',
#  'id': 'efbbb19e-e2f8-4c40-81ec-16721314bfd9',
#  'info': {},
#  'info_exists': None,
#  'mimetype': 'application/zip',
#  'modality': None,
#  'modified': datetime.datetime(2020, 2, 6, 15, 32, 8, 860000, tzinfo=tzutc()),
#  'name': '02166_task.zip',
#  'origin': {'id': 'ttapera@upenn.edu',
#             'method': None,
#             'name': None,
#             'type': 'user',
#             'via': None},
#  'replaced': None,
#  'size': 14395,
#  'tags': [],
#  'type': 'archive',
#  'zip_member_count': None}

# %% [markdown]
# Now, we fetch XCP:

# %%
xcp = fw.lookup('gears/xcpengine-fw')

# %%
xcp # current version 0.0.1_1.00
# Out:
# {'category': 'analysis',
#  'created': datetime.datetime(2020, 3, 21, 22, 57, 47, 163000, tzinfo=tzutc()),
#  'exchange': {'git_commit': None,
#               'rootfs_hash': None,
#               'rootfs_url': 'docker://upenn.flywheel.io/xcpengine-fw@sha256:fc2a0eba63e6d572d5f2ebaf97b4087d8189b5a449a93e597bd2fc9d24af021a'},
#  'gear': {'author': 'Ted Satterthwaite',
#           'cite': 'Ciric, Rastko and Rosen, Adon F. G. and Erus, Guray and '
#                   'Cieslak, Matthew and Adebimpe, Azeez and Cook, Philip A. '
#                   'and Bassett, Danielle S. and Davatzikos, Christos and Wolf, '
#                   'Daniel H. and Satterthwaite, Theodore D., Mitigating head '
#                   'motion artifact in functional connectivity MRI',
#           'command': None,
#           'config': {'analysis_type': {'default': 'xcp',
#                                        'description': ' analysis type: '
#                                                       '[fc,struc,task,cbf]',
#                                        'type': 'string'},
#                      'task_name': {'default': '',
#                                    'description': ' name of the task to '
#                                                   'perform either task '
#                                                   'regression or task ',
#                                    'type': 'string'}},
#           'custom': {'flywheel': {'suite': 'PennBBL'},
#                      'gear-builder': {'category': 'analysis',
#                                       'image': 'pennbbl/xcpengine'}},
#           'description': ' The XCP imaging pipeline (XCP system) for  '
#                          'preprocessing of structural and functional data.',
#           'environment': None,
#           'inputs': {'antsct': {'base': 'file',
#                                 'description': 'Structural output directory',
#                                 'optional': True},
#                      'api_key': {'base': 'api-key'},
#                      'custom_regressors': {'base': 'file',
#                                            'description': 'custom regressors '
#                                                           'already convolved '
#                                                           'with hrf',
#                                            'optional': True},
#                      'designfile': {'base': 'file',
#                                     'description': 'designfile: list all '
#                                                    'modules to run'},
#                      'fmriprepdir': {'base': 'file',
#                                      'description': 'FMRIprep output directory',
#                                      'optional': True},
#                      'img': {'base': 'file',
#                              'description': 'asl or structural image ',
#                              'optional': True},
#                      'm0': {'base': 'file',
#                             'description': 'M0 images for cbf calibration',
#                             'optional': True},
#                      'taskfile': {'base': 'file',
#                                   'description': 'eventtimes files with json  ',
#                                   'optional': True}},
#           'label': 'XCPENGINE: pipeline for processing of  structural and '
#                    'functional data.',
#           'license': 'Other',
#           'maintainer': 'Ted Satterthwaite',
#           'name': 'xcpengine-fw',
#           'source': 'https://github.com/PennBBL/xcpEngine',
#           'url': 'https://xcpengine.readthedocs.io/',
#           'version': '0.0.1_1.00'},
#  'id': '5e769beb7204d510e7cfcf81',
#  'modified': datetime.datetime(2020, 3, 21, 22, 57, 47, 163000, tzinfo=tzutc())}

# %% [markdown]
# An additional input we need is the design file, which is attached to the project. We use the CBF basil strategy, which is in the name of the design file.

# %%
designFile = [x for x in proj.files if "task_acompcor_alff_reho_fcon" in x.name][0]
designFile = proj.get_file(designFile.name)
designFile
# Out:
# {'classification': {},
#  'created': datetime.datetime(2020, 3, 24, 15, 19, 37, 604000, tzinfo=tzutc()),
#  'hash': 'v0-sha384-9e7b971e2575dda29f187fe3e42e5f6b0708cb3cf2f6da4d42e43238c54143f22518caff48bfc61dd715de5280e15015',
#  'id': '310ea9c5-83e8-443f-ad11-4fa3776f150f',
#  'info': {},
#  'info_exists': None,
#  'mimetype': 'application/octet-stream',
#  'modality': None,
#  'modified': datetime.datetime(2020, 3, 24, 15, 19, 36, 695000, tzinfo=tzutc()),
#  'name': 'task_acompcor_alff_reho_fcon.dsn',
#  'origin': {'id': 'larsenb@upenn.edu',
#             'method': None,
#             'name': None,
#             'type': 'user',
#             'via': None},
#  'replaced': None,
#  'size': 3432,
#  'tags': [],
#  'type': None,
#  'zip_member_count': None}

# %% [markdown]
# And here's how we run it:

# %%
eg = sessions[0]

taskfile = get_taskfile(eg)
fmriprep = get_latest_fmriprep(eg)

eg
# Out:
# {'age': 693792000,
#  'analyses': [{'created': datetime.datetime(2020, 1, 10, 20, 27, 11, 784000, tzinfo=tzutc()),
#                'description': None,
#                'files': None,
#                'gear_info': {'category': 'analysis',
#                              'id': '5da887766cbeb000b47d028e',
#                              'name': 'fmriprep-hpc',
#                              'version': '0.1.26_1.2.6-1'},
#                'id': '5e18de1f3a9694007a6c854f',
#                'info': None,
#                'inputs': [{'classification': {},
#                            'created': datetime.datetime(2019, 3, 14, 20, 24, 57, 907000, tzinfo=tzutc()),
#                            'hash': '',
#                            'id': '2d2cea1f-9ed2-4f52-9d6c-8495d3ba4ce5',
#                            'info': {},
#                            'info_exists': None,
#                            'mimetype': 'application/zip',
#                            'modality': None,
#                            'modified': datetime.datetime(2019, 3, 14, 20, 24, 57, 250000, tzinfo=tzutc()),
#                            'name': 'ALPRAZ_805556.PROCESSING.zip',
#                            'origin': {'id': 'harshakethineni@flywheel.io',
#                                       'method': None,
#                                       'name': None,
#                                       'type': 'user',
#                                       'via': None},
#                            'replaced': None,
#                            'size': 576084,
#                            'tags': [],
#                            'type': 'archive',
#                            'zip_member_count': 97}],
#                'job': {'attempt': 1,
#                        'compute_provider_id': '5d8ed960507ac10001ff63e4',
#                        'config': {'config': {'FREESURFER_LICENSE': 'stauffer@upenn.edu\n'
#                                                                    '20217\n'
#                                                                    ' '
#                                                                    '*CNJKge/MKN62\n'
#                                                                    ' '
#                                                                    'FShMG3atCAhWE\n',
#                                              'anat_only': False,
#                                              'aroma_melodic_dimensionality': 'None',
#                                              'bold2t1w_dof': 9,
#                                              'cifti_output': True,
#                                              'fmap_bspline': False,
#                                              'fmap_no_demean': False,
#                                              'force_bbr': False,
#                                              'force_no_bbr': False,
#                                              'force_syn': False,
#                                              'fs_no_reconall': False,
#                                              'ignore': 'fieldmaps',
#                                              'intermediate_files': '',
#                                              'intermediate_folders': '',
#                                              'longitudinal': False,
#                                              'low_mem': False,
#                                              'medial_surface_nan': False,
#                                              'no_submm_recon': False,
#                                              'output_space': 'template '
#                                                              'fsaverage5',
#                                              'save_intermediate_work': False,
#                                              'save_outputs': False,
#                                              'sge-cpu': '8',
#                                              'sge-ram': '64G',
#                                              'sge-short': False,
#                                              'singularity-debug': False,
#                                              'singularity-writable': False,
#                                              'skull_strip_fixed_seed': False,
#                                              'skull_strip_template': 'OASIS',
#                                              'sloppy_mode': False,
#                                              't2s_coreg': False,
#                                              'template': 'MNI152NLin2009cAsym',
#                                              'template_resampling_grid': 'native',
#                                              'use_all_sessions': False,
#                                              'use_aroma': False,
#                                              'use_syn_sdc': False},
#                                   'destination': {'id': '5e18de1f3a9694007a6c854f',
#                                                   'type': 'analysis'},
#                                   'inputs': {'freesurfer_license': {'base': 'file',
#                                                                     'hierarchy': {'id': '5c8ab803f546b600306d7bdc',
#                                                                                   'type': 'project'},
#                                                                     'location': {'name': 'ALPRAZ_805556.PROCESSING.zip',
#                                                                                  'path': '/flywheel/v0/input/freesurfer_license/ALPRAZ_805556.PROCESSING.zip'},
#                                                                     'object': {'classification': {},
#                                                                                'measurements': [],
#                                                                                'mimetype': 'application/zip',
#                                                                                'modality': None,
#                                                                                'size': 576084,
#                                                                                'tags': [],
#                                                                                'type': 'archive'}}}},
#                        'created': datetime.datetime(2020, 1, 10, 20, 27, 11, 987000, tzinfo=tzutc()),
#                        'destination': {'id': '5e18de1f3a9694007a6c854f',
#                                        'type': 'analysis'},
#                        'failure_reason': None,
#                        'gear_id': '5da887766cbeb000b47d028e',
#                        'gear_info': {'category': 'analysis',
#                                      'id': None,
#                                      'name': 'fmriprep-hpc',
#                                      'version': '0.1.26_1.2.6-1'},
#                        'group': None,
#                        'id': '5e18de1f3a9694007a6c8550',
#                        'inputs': {'freesurfer_license': {'id': '5c8ab803f546b600306d7bdc',
#                                                          'name': 'ALPRAZ_805556.PROCESSING.zip',
#                                                          'type': 'project'}},
#                        'label': '',
#                        'modified': datetime.datetime(2020, 1, 10, 20, 28, 4, 294000, tzinfo=tzutc()),
#                        'origin': {'id': 'larsenb@upenn.edu', 'type': 'user'},
#                        'previous_job_id': None,
#                        'profile': {'elapsed_time_ms': None,
#                                    'executor': None,
#                                    'preparation_time_ms': None,
#                                    'total_input_files': 1,
#                                    'total_input_size_bytes': 576084,
#                                    'total_output_files': None,
#                                    'total_output_size_bytes': None,
#                                    'total_time_ms': 50083,
#                                    'upload_time_ms': None,
#                                    'versions': {'core': '10.6.1'}},
#                        'project': None,
#                        'related_container_ids': ['5c8ab804f546b600306d7be4',
#                                                  'bbl',
#                                                  '5e18de1f3a9694007a6c854f',
#                                                  '5c8ab803f546b600306d7bdc',
#                                                  '5c8ab80bf546b6002f6d78e9'],
#                        'request': {'inputs': [{'location': '/',
#                                                'type': 'docker',
#                                                'uri': 'docker.io/pennbbl/fmriprep_fw:0.1.26_1.2.6-1',
#                                                'vu': None},
#                                               {'location': '/flywheel/v0',
#                                                'type': 'scitran',
#                                                'uri': '/jobs/5e18de1f3a9694007a6c8550/config.json',
#                                                'vu': None},
#                                               {'location': '/flywheel/v0/input/freesurfer_license',
#                                                'type': 'scitran',
#                                                'uri': '/projects/5c8ab803f546b600306d7bdc/files/ALPRAZ_805556.PROCESSING.zip',
#                                                'vu': None}],
#                                    'outputs': [{'location': '/flywheel/v0/output',
#                                                 'type': 'scitran',
#                                                 'uri': '/engine?level=analysis&id=5e18de1f3a9694007a6c854f&job=5e18de1f3a9694007a6c8550'}],
#                                    'target': {'command': ['bash',
#                                                           '-c',
#                                                           './run'],
#                                               'dir': '/flywheel/v0',
#                                               'env': {'FW_CONFIG_ANAT_ONLY': 'false',
#                                                       'FW_CONFIG_AROMA_MELODIC_DIMENSIONALITY': 'None',
#                                                       'FW_CONFIG_BOLD2T1W_DOF': '9',
#                                                       'FW_CONFIG_CIFTI_OUTPUT': 'true',
#                                                       'FW_CONFIG_FMAP_BSPLINE': 'false',
#                                                       'FW_CONFIG_FMAP_NO_DEMEAN': 'false',
#                                                       'FW_CONFIG_FORCE_BBR': 'false',
#                                                       'FW_CONFIG_FORCE_NO_BBR': 'false',
#                                                       'FW_CONFIG_FORCE_SYN': 'false',
#                                                       'FW_CONFIG_FREESURFER_LICENSE': 'stauffer@upenn.edu\n'
#                                                                                       '20217\n'
#                                                                                       ' '
#                                                                                       '*CNJKge/MKN62\n'
#                                                                                       ' '
#                                                                                       'FShMG3atCAhWE\n',
#                                                       'FW_CONFIG_FS_NO_RECONALL': 'false',
#                                                       'FW_CONFIG_IGNORE': 'fieldmaps',
#                                                       'FW_CONFIG_INTERMEDIATE_FILES': '',
#                                                       'FW_CONFIG_INTERMEDIATE_FOLDERS': '',
#                                                       'FW_CONFIG_LONGITUDINAL': 'false',
#                                                       'FW_CONFIG_LOW_MEM': 'false',
#                                                       'FW_CONFIG_MEDIAL_SURFACE_NAN': 'false',
#                                                       'FW_CONFIG_NO_SUBMM_RECON': 'false',
#                                                       'FW_CONFIG_OUTPUT_SPACE': 'template '
#                                                                                 'fsaverage5',
#                                                       'FW_CONFIG_SAVE_INTERMEDIATE_WORK': 'false',
#                                                       'FW_CONFIG_SAVE_OUTPUTS': 'false',
#                                                       'FW_CONFIG_SGECPU': '8',
#                                                       'FW_CONFIG_SGERAM': '64G',
#                                                       'FW_CONFIG_SGESHORT': 'false',
#                                                       'FW_CONFIG_SINGULARITYDEBUG': 'false',
#                                                       'FW_CONFIG_SINGULARITYWRITABLE': 'false',
#                                                       'FW_CONFIG_SKULL_STRIP_FIXED_SEED': 'false',
#                                                       'FW_CONFIG_SKULL_STRIP_TEMPLATE': 'OASIS',
#                                                       'FW_CONFIG_SLOPPY_MODE': 'false',
#                                                       'FW_CONFIG_T2S_COREG': 'false',
#                                                       'FW_CONFIG_TEMPLATE': 'MNI152NLin2009cAsym',
#                                                       'FW_CONFIG_TEMPLATE_RESAMPLING_GRID': 'native',
#                                                       'FW_CONFIG_USE_ALL_SESSIONS': 'false',
#                                                       'FW_CONFIG_USE_AROMA': 'false',
#                                                       'FW_CONFIG_USE_SYN_SDC': 'false',
#                                                       'PATH': '/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin'}}},
#                        'retried': None,
#                        'saved_files': [],
#                        'state': 'cancelled',
#                        'tags': ['analysis', 'fmriprep-hpc'],
#                        'transitions': {'cancelled': datetime.datetime(2020, 1, 10, 20, 28, 4, 294000, tzinfo=tzutc()),
#                                        'complete': None,
#                                        'failed': None,
#                                        'running': datetime.datetime(2020, 1, 10, 20, 27, 14, 211000, tzinfo=tzutc())}},
#                'label': 'fmriprep_SDK_002258_2020-01-10_15:27',
#                'modified': datetime.datetime(2020, 1, 10, 20, 27, 12, 193000, tzinfo=tzutc()),
#                'notes': None,
#                'parent': {'id': '5c8ab80bf546b6002f6d78e9', 'type': 'session'},
#                'parents': {'acquisition': None,
#                            'analysis': None,
#                            'group': 'bbl',
#                            'project': '5c8ab803f546b600306d7bdc',
#                            'session': '5c8ab80bf546b6002f6d78e9',
#                            'subject': '5c8ab804f546b600306d7be4'},
#                'revision': 2,
#                'tags': None},
#               {'created': datetime.datetime(2020, 1, 10, 20, 49, 17, 824000, tzinfo=tzutc()),
#                'description': None,
#                'files': [],
#                'gear_info': {'category': 'analysis',
#                              'id': '5da887766cbeb000b47d028e',
#                              'name': 'fmriprep-hpc',
#                              'version': '0.1.26_1.2.6-1'},
#                'id': '5e18e34d3a9694005968e847',
#                'info': None,
#                'inputs': [{'classification': {},
#                            'created': datetime.datetime(2019, 3, 14, 20, 24, 57, 907000, tzinfo=tzutc()),
#                            'hash': '',
#                            'id': '2d2cea1f-9ed2-4f52-9d6c-8495d3ba4ce5',
#                            'info': {},
#                            'info_exists': None,
#                            'mimetype': 'application/zip',
#                            'modality': None,
#                            'modified': datetime.datetime(2019, 3, 14, 20, 24, 57, 250000, tzinfo=tzutc()),
#                            'name': 'ALPRAZ_805556.PROCESSING.zip',
#                            'origin': {'id': 'harshakethineni@flywheel.io',
#                                       'method': None,
#                                       'name': None,
#                                       'type': 'user',
#                                       'via': None},
#                            'replaced': None,
#                            'size': 576084,
#                            'tags': [],
#                            'type': 'archive',
#                            'zip_member_count': 97}],
#                'job': {'attempt': 1,
#                        'compute_provider_id': '5d8ed960507ac10001ff63e4',
#                        'config': {'config': {'FREESURFER_LICENSE': 'stauffer@upenn.edu\n'
#                                                                    '20217\n'
#                                                                    ' '
#                                                                    '*CNJKge/MKN62\n'
#                                                                    ' '
#                                                                    'FShMG3atCAhWE\n',
#                                              'anat_only': False,
#                                              'aroma_melodic_dimensionality': 'None',
#                                              'bold2t1w_dof': 9,
#                                              'cifti_output': True,
#                                              'fmap_bspline': False,
#                                              'fmap_no_demean': False,
#                                              'force_bbr': False,
#                                              'force_no_bbr': False,
#                                              'force_syn': False,
#                                              'fs_no_reconall': False,
#                                              'ignore': 'fieldmaps',
#                                              'intermediate_files': '',
#                                              'intermediate_folders': '',
#                                              'longitudinal': False,
#                                              'low_mem': False,
#                                              'medial_surface_nan': False,
#                                              'no_submm_recon': False,
#                                              'output_space': 'template '
#                                                              'fsaverage5',
#                                              'save_intermediate_work': False,
#                                              'save_outputs': False,
#                                              'sge-cpu': '8',
#                                              'sge-ram': '64G',
#                                              'sge-short': False,
#                                              'singularity-debug': False,
#                                              'singularity-writable': False,
#                                              'skull_strip_fixed_seed': False,
#                                              'skull_strip_template': 'OASIS',
#                                              'sloppy_mode': False,
#                                              't2s_coreg': False,
#                                              'template': 'MNI152NLin2009cAsym',
#                                              'template_resampling_grid': 'native',
#                                              'use_all_sessions': False,
#                                              'use_aroma': False,
#                                              'use_syn_sdc': False},
#                                   'destination': {'id': '5e18e34d3a9694005968e847',
#                                                   'type': 'analysis'},
#                                   'inputs': {'freesurfer_license': {'base': 'file',
#                                                                     'hierarchy': {'id': '5c8ab803f546b600306d7bdc',
#                                                                                   'type': 'project'},
#                                                                     'location': {'name': 'ALPRAZ_805556.PROCESSING.zip',
#                                                                                  'path': '/flywheel/v0/input/freesurfer_license/ALPRAZ_805556.PROCESSING.zip'},
#                                                                     'object': {'classification': {},
#                                                                                'measurements': [],
#                                                                                'mimetype': 'application/zip',
#                                                                                'modality': None,
#                                                                                'size': 576084,
#                                                                                'tags': [],
#                                                                                'type': 'archive'}}}},
#                        'created': datetime.datetime(2020, 1, 10, 20, 49, 18, 2000, tzinfo=tzutc()),
#                        'destination': {'id': '5e18e34d3a9694005968e847',
#                                        'type': 'analysis'},
#                        'failure_reason': None,
#                        'gear_id': '5da887766cbeb000b47d028e',
#                        'gear_info': {'category': 'analysis',
#                                      'id': None,
#                                      'name': 'fmriprep-hpc',
#                                      'version': '0.1.26_1.2.6-1'},
#                        'group': None,
#                        'id': '5e18e34e3a9694005968e848',
#                        'inputs': {'freesurfer_license': {'id': '5c8ab803f546b600306d7bdc',
#                                                          'name': 'ALPRAZ_805556.PROCESSING.zip',
#                                                          'type': 'project'}},
#                        'label': '',
#                        'modified': datetime.datetime(2020, 1, 10, 22, 34, 46, 706000, tzinfo=tzutc()),
#                        'origin': {'id': 'ttapera@upenn.edu', 'type': 'user'},
#                        'previous_job_id': None,
#                        'profile': {'elapsed_time_ms': 1379280,
#                                    'executor': {'cpu_cores': 16,
#                                                 'disk_bytes': None,
#                                                 'gpu': None,
#                                                 'host': None,
#                                                 'instance_type': None,
#                                                 'memory_bytes': 202269896704,
#                                                 'name': '2119fmn045',
#                                                 'swap_bytes': 4294963200},
#                                    'preparation_time_ms': None,
#                                    'total_input_files': 1,
#                                    'total_input_size_bytes': 576084,
#                                    'total_output_files': 0,
#                                    'total_output_size_bytes': 0,
#                                    'total_time_ms': 6326548,
#                                    'upload_time_ms': None,
#                                    'versions': {'core': '10.6.1'}},
#                        'project': None,
#                        'related_container_ids': ['5c8ab804f546b600306d7be4',
#                                                  'bbl',
#                                                  '5c8ab80bf546b6002f6d78e9',
#                                                  '5c8ab803f546b600306d7bdc',
#                                                  '5e18e34d3a9694005968e847'],
#                        'request': {'inputs': [{'location': '/',
#                                                'type': 'docker',
#                                                'uri': 'docker.io/pennbbl/fmriprep_fw:0.1.26_1.2.6-1',
#                                                'vu': None},
#                                               {'location': '/flywheel/v0',
#                                                'type': 'scitran',
#                                                'uri': '/jobs/5e18e34e3a9694005968e848/config.json',
#                                                'vu': None},
#                                               {'location': '/flywheel/v0/input/freesurfer_license',
#                                                'type': 'scitran',
#                                                'uri': '/projects/5c8ab803f546b600306d7bdc/files/ALPRAZ_805556.PROCESSING.zip',
#                                                'vu': None}],
#                                    'outputs': [{'location': '/flywheel/v0/output',
#                                                 'type': 'scitran',
#                                                 'uri': '/engine?level=analysis&id=5e18e34d3a9694005968e847&job=5e18e34e3a9694005968e848'}],
#                                    'target': {'command': ['bash',
#                                                           '-c',
#                                                           './run'],
#                                               'dir': '/flywheel/v0',
#                                               'env': {'FW_CONFIG_ANAT_ONLY': 'false',
#                                                       'FW_CONFIG_AROMA_MELODIC_DIMENSIONALITY': 'None',
#                                                       'FW_CONFIG_BOLD2T1W_DOF': '9',
#                                                       'FW_CONFIG_CIFTI_OUTPUT': 'true',
#                                                       'FW_CONFIG_FMAP_BSPLINE': 'false',
#                                                       'FW_CONFIG_FMAP_NO_DEMEAN': 'false',
#                                                       'FW_CONFIG_FORCE_BBR': 'false',
#                                                       'FW_CONFIG_FORCE_NO_BBR': 'false',
#                                                       'FW_CONFIG_FORCE_SYN': 'false',
#                                                       'FW_CONFIG_FREESURFER_LICENSE': 'stauffer@upenn.edu\n'
#                                                                                       '20217\n'
#                                                                                       ' '
#                                                                                       '*CNJKge/MKN62\n'
#                                                                                       ' '
#                                                                                       'FShMG3atCAhWE\n',
#                                                       'FW_CONFIG_FS_NO_RECONALL': 'false',
#                                                       'FW_CONFIG_IGNORE': 'fieldmaps',
#                                                       'FW_CONFIG_INTERMEDIATE_FILES': '',
#                                                       'FW_CONFIG_INTERMEDIATE_FOLDERS': '',
#                                                       'FW_CONFIG_LONGITUDINAL': 'false',
#                                                       'FW_CONFIG_LOW_MEM': 'false',
#                                                       'FW_CONFIG_MEDIAL_SURFACE_NAN': 'false',
#                                                       'FW_CONFIG_NO_SUBMM_RECON': 'false',
#                                                       'FW_CONFIG_OUTPUT_SPACE': 'template '
#                                                                                 'fsaverage5',
#                                                       'FW_CONFIG_SAVE_INTERMEDIATE_WORK': 'false',
#                                                       'FW_CONFIG_SAVE_OUTPUTS': 'false',
#                                                       'FW_CONFIG_SGECPU': '8',
#                                                       'FW_CONFIG_SGERAM': '64G',
#                                                       'FW_CONFIG_SGESHORT': 'false',
#                                                       'FW_CONFIG_SINGULARITYDEBUG': 'false',
#                                                       'FW_CONFIG_SINGULARITYWRITABLE': 'false',
#                                                       'FW_CONFIG_SKULL_STRIP_FIXED_SEED': 'false',
#                                                       'FW_CONFIG_SKULL_STRIP_TEMPLATE': 'OASIS',
#                                                       'FW_CONFIG_SLOPPY_MODE': 'false',
#                                                       'FW_CONFIG_T2S_COREG': 'false',
#                                                       'FW_CONFIG_TEMPLATE': 'MNI152NLin2009cAsym',
#                                                       'FW_CONFIG_TEMPLATE_RESAMPLING_GRID': 'native',
#                                                       'FW_CONFIG_USE_ALL_SESSIONS': 'false',
#                                                       'FW_CONFIG_USE_AROMA': 'false',
#                                                       'FW_CONFIG_USE_SYN_SDC': 'false',
#                                                       'PATH': '/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin'}}},
#                        'retried': None,
#                        'saved_files': [],
#                        'state': 'failed',
#                        'tags': ['analysis', 'fmriprep-hpc'],
#                        'transitions': {'cancelled': None,
#                                        'complete': None,
#                                        'failed': datetime.datetime(2020, 1, 10, 22, 34, 46, 706000, tzinfo=tzutc()),
#                                        'running': datetime.datetime(2020, 1, 10, 20, 49, 20, 158000, tzinfo=tzutc())}},
#                'label': 'fmriprep_SDK_002258_2020-01-10_15:49',
#                'modified': datetime.datetime(2020, 1, 10, 22, 34, 46, 620000, tzinfo=tzutc()),
#                'notes': None,
#                'parent': {'id': '5c8ab80bf546b6002f6d78e9', 'type': 'session'},
#                'parents': {'acquisition': None,
#                            'analysis': None,
#                            'group': 'bbl',
#                            'project': '5c8ab803f546b600306d7bdc',
#                            'session': '5c8ab80bf546b6002f6d78e9',
#                            'subject': '5c8ab804f546b600306d7be4'},
#                'revision': 3,
#                'tags': None},
#               {'created': datetime.datetime(2020, 1, 13, 15, 31, 27, 181000, tzinfo=tzutc()),
#                'description': None,
#                'files': [],
#                'gear_info': {'category': 'analysis',
#                              'id': '5da887766cbeb000b47d028e',
#                              'name': 'fmriprep-hpc',
#                              'version': '0.1.26_1.2.6-1'},
#                'id': '5e1c8d4f3a9694005b6cc28b',
#                'info': None,
#                'inputs': [{'classification': {},
#                            'created': datetime.datetime(2019, 3, 14, 20, 24, 57, 907000, tzinfo=tzutc()),
#                            'hash': '',
#                            'id': '2d2cea1f-9ed2-4f52-9d6c-8495d3ba4ce5',
#                            'info': {},
#                            'info_exists': None,
#                            'mimetype': 'application/zip',
#                            'modality': None,
#                            'modified': datetime.datetime(2019, 3, 14, 20, 24, 57, 250000, tzinfo=tzutc()),
#                            'name': 'ALPRAZ_805556.PROCESSING.zip',
#                            'origin': {'id': 'harshakethineni@flywheel.io',
#                                       'method': None,
#                                       'name': None,
#                                       'type': 'user',
#                                       'via': None},
#                            'replaced': None,
#                            'size': 576084,
#                            'tags': [],
#                            'type': 'archive',
#                            'zip_member_count': 97}],
#                'job': {'attempt': 1,
#                        'compute_provider_id': '5d8ed960507ac10001ff63e4',
#                        'config': {'config': {'FREESURFER_LICENSE': 'bart.larsen@pennmedicine.upenn.edu\n'
#                                                                    '45679\n'
#                                                                    ' '
#                                                                    '*CFIo/1k.PzbY\n'
#                                                                    ' '
#                                                                    'FS5S6AgJ3bOnk\n',
#                                              'anat_only': False,
#                                              'aroma_melodic_dimensionality': 'None',
#                                              'bold2t1w_dof': 9,
#                                              'cifti_output': True,
#                                              'fmap_bspline': False,
#                                              'fmap_no_demean': False,
#                                              'force_bbr': False,
#                                              'force_no_bbr': False,
#                                              'force_syn': False,
#                                              'fs_no_reconall': False,
#                                              'ignore': 'fieldmaps',
#                                              'intermediate_files': '',
#                                              'intermediate_folders': '',
#                                              'longitudinal': False,
#                                              'low_mem': False,
#                                              'medial_surface_nan': False,
#                                              'no_submm_recon': False,
#                                              'output_space': 'template '
#                                                              'fsaverage5',
#                                              'save_intermediate_work': False,
#                                              'save_outputs': False,
#                                              'sge-cpu': '8',
#                                              'sge-ram': '64G',
#                                              'sge-short': False,
#                                              'singularity-debug': False,
#                                              'singularity-writable': False,
#                                              'skull_strip_fixed_seed': False,
#                                              'skull_strip_template': 'OASIS',
#                                              'sloppy_mode': False,
#                                              't2s_coreg': False,
#                                              'template': 'MNI152NLin2009cAsym',
#                                              'template_resampling_grid': 'native',
#                                              'use_all_sessions': False,
#                                              'use_aroma': False,
#                                              'use_syn_sdc': False},
#                                   'destination': {'id': '5e1c8d4f3a9694005b6cc28b',
#                                                   'type': 'analysis'},
#                                   'inputs': {'freesurfer_license': {'base': 'file',
#                                                                     'hierarchy': {'id': '5c8ab803f546b600306d7bdc',
#                                                                                   'type': 'project'},
#                                                                     'location': {'name': 'ALPRAZ_805556.PROCESSING.zip',
#                                                                                  'path': '/flywheel/v0/input/freesurfer_license/ALPRAZ_805556.PROCESSING.zip'},
#                                                                     'object': {'classification': {},
#                                                                                'measurements': [],
#                                                                                'mimetype': 'application/zip',
#                                                                                'modality': None,
#                                                                                'size': 576084,
#                                                                                'tags': [],
#                                                                                'type': 'archive'}}}},
#                        'created': datetime.datetime(2020, 1, 13, 15, 31, 27, 471000, tzinfo=tzutc()),
#                        'destination': {'id': '5e1c8d4f3a9694005b6cc28b',
#                                        'type': 'analysis'},
#                        'failure_reason': None,
#                        'gear_id': '5da887766cbeb000b47d028e',
#                        'gear_info': {'category': 'analysis',
#                                      'id': None,
#                                      'name': 'fmriprep-hpc',
#                                      'version': '0.1.26_1.2.6-1'},
#                        'group': None,
#                        'id': '5e1c8d4f3a9694005b6cc292',
#                        'inputs': {'freesurfer_license': {'id': '5c8ab803f546b600306d7bdc',
#                                                          'name': 'ALPRAZ_805556.PROCESSING.zip',
#                                                          'type': 'project'}},
#                        'label': '',
#                        'modified': datetime.datetime(2020, 1, 13, 15, 54, 14, 16000, tzinfo=tzutc()),
#                        'origin': {'id': 'larsenb@upenn.edu', 'type': 'user'},
#                        'previous_job_id': None,
#                        'profile': {'elapsed_time_ms': 1305324,
#                                    'executor': {'cpu_cores': 16,
#                                                 'disk_bytes': None,
#                                                 'gpu': None,
#                                                 'host': None,
#                                                 'instance_type': None,
#                                                 'memory_bytes': 405194407936,
#                                                 'name': '2119fmn001',
#                                                 'swap_bytes': 4294963200},
#                                    'preparation_time_ms': None,
#                                    'total_input_files': 1,
#                                    'total_input_size_bytes': 576084,
#                                    'total_output_files': 0,
#                                    'total_output_size_bytes': 0,
#                                    'total_time_ms': 1362197,
#                                    'upload_time_ms': None,
#                                    'versions': {'core': '10.6.1'}},
#                        'project': None,
#                        'related_container_ids': ['5c8ab804f546b600306d7be4',
#                                                  'bbl',
#                                                  '5c8ab80bf546b6002f6d78e9',
#                                                  '5c8ab803f546b600306d7bdc',
#                                                  '5e1c8d4f3a9694005b6cc28b'],
#                        'request': {'inputs': [{'location': '/',
#                                                'type': 'docker',
#                                                'uri': 'docker.io/pennbbl/fmriprep_fw:0.1.26_1.2.6-1',
#                                                'vu': None},
#                                               {'location': '/flywheel/v0',
#                                                'type': 'scitran',
#                                                'uri': '/jobs/5e1c8d4f3a9694005b6cc292/config.json',
#                                                'vu': None},
#                                               {'location': '/flywheel/v0/input/freesurfer_license',
#                                                'type': 'scitran',
#                                                'uri': '/projects/5c8ab803f546b600306d7bdc/files/ALPRAZ_805556.PROCESSING.zip',
#                                                'vu': None}],
#                                    'outputs': [{'location': '/flywheel/v0/output',
#                                                 'type': 'scitran',
#                                                 'uri': '/engine?level=analysis&id=5e1c8d4f3a9694005b6cc28b&job=5e1c8d4f3a9694005b6cc292'}],
#                                    'target': {'command': ['bash',
#                                                           '-c',
#                                                           './run'],
#                                               'dir': '/flywheel/v0',
#                                               'env': {'FW_CONFIG_ANAT_ONLY': 'false',
#                                                       'FW_CONFIG_AROMA_MELODIC_DIMENSIONALITY': 'None',
#                                                       'FW_CONFIG_BOLD2T1W_DOF': '9',
#                                                       'FW_CONFIG_CIFTI_OUTPUT': 'true',
#                                                       'FW_CONFIG_FMAP_BSPLINE': 'false',
#                                                       'FW_CONFIG_FMAP_NO_DEMEAN': 'false',
#                                                       'FW_CONFIG_FORCE_BBR': 'false',
#                                                       'FW_CONFIG_FORCE_NO_BBR': 'false',
#                                                       'FW_CONFIG_FORCE_SYN': 'false',
#                                                       'FW_CONFIG_FREESURFER_LICENSE': 'bart.larsen@pennmedicine.upenn.edu\n'
#                                                                                       '45679\n'
#                                                                                       ' '
#                                                                                       '*CFIo/1k.PzbY\n'
#                                                                                       ' '
#                                                                                       'FS5S6AgJ3bOnk\n',
#                                                       'FW_CONFIG_FS_NO_RECONALL': 'false',
#                                                       'FW_CONFIG_IGNORE': 'fieldmaps',
#                                                       'FW_CONFIG_INTERMEDIATE_FILES': '',
#                                                       'FW_CONFIG_INTERMEDIATE_FOLDERS': '',
#                                                       'FW_CONFIG_LONGITUDINAL': 'false',
#                                                       'FW_CONFIG_LOW_MEM': 'false',
#                                                       'FW_CONFIG_MEDIAL_SURFACE_NAN': 'false',
#                                                       'FW_CONFIG_NO_SUBMM_RECON': 'false',
#                                                       'FW_CONFIG_OUTPUT_SPACE': 'template '
#                                                                                 'fsaverage5',
#                                                       'FW_CONFIG_SAVE_INTERMEDIATE_WORK': 'false',
#                                                       'FW_CONFIG_SAVE_OUTPUTS': 'false',
#                                                       'FW_CONFIG_SGECPU': '8',
#                                                       'FW_CONFIG_SGERAM': '64G',
#                                                       'FW_CONFIG_SGESHORT': 'false',
#                                                       'FW_CONFIG_SINGULARITYDEBUG': 'false',
#                                                       'FW_CONFIG_SINGULARITYWRITABLE': 'false',
#                                                       'FW_CONFIG_SKULL_STRIP_FIXED_SEED': 'false',
#                                                       'FW_CONFIG_SKULL_STRIP_TEMPLATE': 'OASIS',
#                                                       'FW_CONFIG_SLOPPY_MODE': 'false',
#                                                       'FW_CONFIG_T2S_COREG': 'false',
#                                                       'FW_CONFIG_TEMPLATE': 'MNI152NLin2009cAsym',
#                                                       'FW_CONFIG_TEMPLATE_RESAMPLING_GRID': 'native',
#                                                       'FW_CONFIG_USE_ALL_SESSIONS': 'false',
#                                                       'FW_CONFIG_USE_AROMA': 'false',
#                                                       'FW_CONFIG_USE_SYN_SDC': 'false',
#                                                       'PATH': '/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin'}}},
#                        'retried': None,
#                        'saved_files': [],
#                        'state': 'failed',
#                        'tags': ['analysis', 'fmriprep-hpc'],
#                        'transitions': {'cancelled': None,
#                                        'complete': None,
#                                        'failed': datetime.datetime(2020, 1, 13, 15, 54, 14, 16000, tzinfo=tzutc()),
#                                        'running': datetime.datetime(2020, 1, 13, 15, 31, 31, 819000, tzinfo=tzutc())}},
#                'label': 'fmriprep_SDK_002258_2020-01-13_10:31',
#                'modified': datetime.datetime(2020, 1, 13, 15, 54, 13, 776000, tzinfo=tzutc()),
#                'notes': None,
#                'parent': {'id': '5c8ab80bf546b6002f6d78e9', 'type': 'session'},
#                'parents': {'acquisition': None,
#                            'analysis': None,
#                            'group': 'bbl',
#                            'project': '5c8ab803f546b600306d7bdc',
#                            'session': '5c8ab80bf546b6002f6d78e9',
#                            'subject': '5c8ab804f546b600306d7be4'},
#                'revision': 3,
#                'tags': None},
#               {'created': datetime.datetime(2020, 1, 13, 16, 55, 6, 407000, tzinfo=tzutc()),
#                'description': None,
#                'files': [{'classification': {},
#                           'created': datetime.datetime(2020, 1, 13, 17, 19, 16, 135000, tzinfo=tzutc()),
#                           'hash': 'v0-sha384-341a460f813546bf4de5a8e19ed36bca2bfb4afd46cebad2c46308996d1e7cdc4bb27e3f171ceca85e8831a5142467b2',
#                           'id': '1e4b3c42-685c-4699-9df6-157d39189640',
#                           'info': {},
#                           'info_exists': None,
#                           'mimetype': 'application/zip',
#                           'modality': None,
#                           'modified': datetime.datetime(2020, 1, 13, 17, 19, 16, 135000, tzinfo=tzutc()),
#                           'name': 'debug_fmriprep_work_5e1ca0ea3a969400596a28e5.zip',
#                           'origin': {'id': '5e1ca0ea3a969400596a28e6',
#                                      'method': None,
#                                      'name': None,
#                                      'type': 'job',
#                                      'via': None},
#                           'replaced': None,
#                           'size': 2032899518,
#                           'tags': [],
#                           'type': 'archive',
#                           'zip_member_count': None},
#                          {'classification': {},
#                           'created': datetime.datetime(2020, 1, 13, 17, 19, 16, 135000, tzinfo=tzutc()),
#                           'hash': 'v0-sha384-1b4863a158f99b962c4aaf7abc08a7b9e36507c2586e3b77d03e51195c2a79949c33dfdd6812e2e0a1ca309740f3b63a',
#                           'id': '39e731a0-eeba-4331-a848-e4aac6536428',
#                           'info': {},
#                           'info_exists': None,
#                           'mimetype': 'application/zip',
#                           'modality': None,
#                           'modified': datetime.datetime(2020, 1, 13, 17, 19, 16, 135000, tzinfo=tzutc()),
#                           'name': 'debug_fmriprep_5e1ca0ea3a969400596a28e5.zip',
# ...
#                                    'total_input_size_bytes': 1393568235,
#                                    'total_output_files': None,
#                                    'total_output_size_bytes': None,
#                                    'total_time_ms': None,
#                                    'upload_time_ms': None,
#                                    'versions': {'core': '11.0.1'}},
#                        'project': None,
#                        'related_container_ids': ['5e7b8ab77204d526a7cfcfc3',
#                                                  'bbl',
#                                                  '5c8ab803f546b600306d7bdc',
#                                                  '5e32fccf6dea3102562a7432',
#                                                  '5c8ab80bf546b6002f6d78e9',
#                                                  '5c8ab804f546b600306d7be4'],
#                        'request': None,
#                        'retried': None,
#                        'saved_files': [],
#                        'state': 'cancelled',
#                        'tags': ['analysis', 'xcpengine-fw'],
#                        'transitions': {'cancelled': datetime.datetime(2020, 3, 25, 16, 46, 40, 942000, tzinfo=tzutc()),
#                                        'complete': None,
#                                        'failed': None,
#                                        'running': None}},
#                'label': 'XCP_SDK_TASK_2020-03-25 12:45:43.779480',
#                'modified': datetime.datetime(2020, 3, 25, 16, 45, 43, 899000, tzinfo=tzutc()),
#                'notes': None,
#                'parent': {'id': '5c8ab80bf546b6002f6d78e9', 'type': 'session'},
#                'parents': {'acquisition': None,
#                            'analysis': None,
#                            'group': 'bbl',
#                            'project': '5c8ab803f546b600306d7bdc',
#                            'session': '5c8ab80bf546b6002f6d78e9',
#                            'subject': '5c8ab804f546b600306d7be4'},
#                'revision': 2,
#                'tags': None}],
#  'created': datetime.datetime(2019, 3, 14, 20, 22, 34, 785000, tzinfo=tzutc()),
#  'files': [{'classification': {},
#             'created': datetime.datetime(2019, 3, 14, 20, 24, 57, 352000, tzinfo=tzutc()),
#             'hash': '',
#             'id': 'fa6195f5-91ba-4baa-8807-fbe983d4dafe',
#             'info': {},
#             'info_exists': None,
#             'mimetype': 'text/xml',
#             'modality': None,
#             'modified': datetime.datetime(2019, 3, 14, 20, 24, 56, 868000, tzinfo=tzutc()),
#             'name': '002258_20110413_233831.xml',
#             'origin': {'id': 'harshakethineni@flywheel.io',
#                        'method': None,
#                        'name': None,
#                        'type': 'user',
#                        'via': None},
#             'replaced': None,
#             'size': 21692,
#             'tags': [],
#             'type': 'markup',
#             'zip_member_count': None},
#            {'classification': {},
#             'created': datetime.datetime(2019, 3, 14, 20, 24, 57, 411000, tzinfo=tzutc()),
#             'hash': '',
#             'id': '81464336-a39a-4c96-af8f-3e0b7f5eb020',
#             'info': {},
#             'info_exists': None,
#             'mimetype': 'application/octet-stream',
#             'modality': None,
#             'modified': datetime.datetime(2019, 3, 14, 20, 24, 56, 855000, tzinfo=tzutc()),
#             'name': 'dcmtoxnat.log',
#             'origin': {'id': 'harshakethineni@flywheel.io',
#                        'method': None,
#                        'name': None,
#                        'type': 'user',
#                        'via': None},
#             'replaced': None,
#             'size': 5210,
#             'tags': [],
#             'type': 'log',
#             'zip_member_count': None},
#            {'classification': {},
#             'created': datetime.datetime(2020, 1, 14, 21, 27, 51, 966000, tzinfo=tzutc()),
#             'hash': 'v0-sha384-43ed0fee1daaa62bde7d7f08c50476582ecfd216c18270c91af099adbbb092f5fcad7296bbd9da9723b4285005dbf19c',
#             'id': '1590fcba-0f4e-4029-8c1a-33b5860487cb',
#             'info': {},
#             'info_exists': None,
#             'mimetype': 'application/octet-stream',
#             'modality': None,
#             'modified': datetime.datetime(2020, 1, 14, 21, 27, 51, 613000, tzinfo=tzutc()),
#             'name': 'README.md',
#             'origin': {'id': 'ttapera@upenn.edu',
#                        'method': None,
#                        'name': None,
#                        'type': 'user',
#                        'via': None},
#             'replaced': None,
#             'size': 234,
#             'tags': [],
#             'type': 'markdown',
#             'zip_member_count': None},
#            {'classification': {},
#             'created': datetime.datetime(2020, 1, 15, 6, 43, 38, 837000, tzinfo=tzutc()),
#             'hash': 'v0-sha384-90ce07daa06d053fc9d1dec3a70200fc861dd2dc2518f26e96068a13c5cc107d4fbaef92e19c9a5a5b5c1aeecd93af23',
#             'id': '7d572247-c400-4b70-a9a4-e33963704486',
#             'info': {},
#             'info_exists': None,
#             'mimetype': 'application/octet-stream',
#             'modality': None,
#             'modified': datetime.datetime(2020, 1, 15, 6, 43, 38, 466000, tzinfo=tzutc()),
#             'name': 'task_alpraz_rps.dsn',
#             'origin': {'id': 'adebimpe@upenn.edu',
#                        'method': None,
#                        'name': None,
#                        'type': 'user',
#                        'via': None},
#             'replaced': None,
#             'size': 2666,
#             'tags': [],
#             'type': None,
#             'zip_member_count': None},
#            {'classification': {},
#             'created': datetime.datetime(2020, 2, 6, 15, 32, 6, 225000, tzinfo=tzutc()),
#             'hash': 'v0-sha384-0c84296b6eb49cb1953b68eb721c95a966be2bf50b72041b633acece570d979b1348d07cdcff7f5a95d65491064961de',
#             'id': '81adc970-cf5b-490c-9b23-f1c62e20985c',
#             'info': {},
#             'info_exists': None,
#             'mimetype': 'application/zip',
#             'modality': None,
#             'modified': datetime.datetime(2020, 2, 6, 15, 32, 5, 795000, tzinfo=tzutc()),
#             'name': '02258_task.zip',
#             'origin': {'id': 'ttapera@upenn.edu',
#                        'method': None,
#                        'name': None,
#                        'type': 'user',
#                        'via': None},
#             'replaced': None,
#             'size': 14524,
#             'tags': [],
#             'type': 'archive',
#             'zip_member_count': None}],
#  'group': 'bbl',
#  'id': '5c8ab80bf546b6002f6d78e9',
#  'info': {'SeriesUIDs': ['1.3.12.2.1107.5.2.13.20523.30000009061711545520300000149',
#                          '1.3.12.2.1107.5.2.13.20523.30000009061712304278100010513',
#                          '1.3.12.2.1107.5.2.13.20523.30000009061712304278100010517',
#                          '1.3.12.2.1107.5.2.13.20523.30000009061712304278100010528',
#                          '1.3.12.2.1107.5.2.13.20523.30000009061712304278100010530',
#                          '1.3.12.2.1107.5.2.13.20523.30000009061712304278100010952',
#                          '1.3.12.2.1107.5.2.13.20523.30000009061712304278100010954',
#                          '1.3.12.2.1107.5.2.13.20523.30000009061712304278100010960',
#                          '1.3.12.2.1107.5.2.13.20523.30000009061712304278100010962',
#                          '1.3.12.2.1107.5.2.13.20523.30000009061712304278100011384',
#                          '1.3.12.2.1107.5.2.13.20523.30000009061712304278100010173',
#                          '1.3.12.2.1107.5.2.13.20523.30000009061712304278100010335',
#                          '1.3.12.2.1107.5.2.13.20523.30000009061712304278100010337',
#                          '1.3.12.2.1107.5.2.13.20523.30000009061721214535900000010',
#                          '1.3.12.2.1107.5.2.13.20523.30000009061712304278100010499',
#                          '1.3.12.2.1107.5.2.13.20523.30000009061712304278100010501',
#                          '1.3.12.2.1107.5.2.13.20523.30000009061712304278100010507',
#                          '1.3.12.2.1107.5.2.13.20523.30000009061712304278100010510'],
#           'StudyUIDs': ['1.2.840.113745.101000.1002000.39979.4437.26413131'],
#           'subject_raw': {'sex': 'male'}},
#  'info_exists': None,
#  'label': '002258',
#  'modified': datetime.datetime(2020, 3, 23, 13, 43, 41, 170000, tzinfo=tzutc()),
#  'notes': [],
#  'operator': 'POD',
#  'parents': {'acquisition': None,
#              'analysis': None,
#              'group': 'bbl',
#              'project': '5c8ab803f546b600306d7bdc',
#              'session': None,
#              'subject': '5c8ab804f546b600306d7be4'},
#  'permissions': [{'access': 'admin', 'id': 'harshakethineni@flywheel.io'},
#                  {'access': 'admin', 'id': 'kruparel@pennmedicine.upenn.edu'},
#                  {'access': 'admin', 'id': 'kalebfischer@flywheel.io'},
#                  {'access': 'admin', 'id': 'mcieslak@upenn.edu'},
#                  {'access': 'admin', 'id': 'kruparel@upenn.edu'},
#                  {'access': 'rw', 'id': 'roalf@upenn.edu'},
#                  {'access': 'admin', 'id': 'adebimpe@upenn.edu'},
#                  {'access': 'rw', 'id': 'annaxu@upenn.edu'},
#                  {'access': 'admin', 'id': 'ttapera@upenn.edu'},
#                  {'access': 'rw', 'id': 'butellyn@upenn.edu'},
#                  {'access': 'admin', 'id': 'sattertt@upenn.edu'},
#                  {'access': 'rw', 'id': 'sophia.linguiti@upenn.edu'},
#                  {'access': 'rw', 'id': 'pinesa@upenn.edu'},
#                  {'access': 'rw', 'id': 'linguiti@upenn.edu'},
#                  {'access': 'ro', 'id': 'jenna.kantor@pennmedicine.upenn.edu'},
#                  {'access': 'rw', 'id': 'jrkantor@upenn.edu'},
#                  {'access': 'ro', 'id': 'radreview@upenn.edu'},
#                  {'access': 'admin', 'id': 'larsenb@upenn.edu'},
#                  {'access': 'rw', 'id': 'blarsen@upenn.edu'},
#                  {'access': 'ro', 'id': 'radreview@pennbrain.upenn.edu'},
#                  {'access': 'rw', 'id': 'gbaum@upenn.edu'},
#                  {'access': 'rw', 'id': 'zaixucui@upenn.edu'},
#                  {'access': 'rw', 'id': 'diegodav@upenn.edu'},
#                  {'access': 'rw', 'id': 'hxia@upenn.edu'},
#                  {'access': 'rw', 'id': 'moberg@upenn.edu'},
#                  {'access': 'rw', 'id': 'kpiiwaa@upenn.edu'},
#                  {'access': 'rw', 'id': 'krmurtha@upenn.edu'},
#                  {'access': 'rw', 'id': 'apines@upenn.edu'},
#                  {'access': 'rw', 'id': 'sagerush@upenn.edu'},
#                  {'access': 'rw', 'id': 'adrose@upenn.edu'},
#                  {'access': 'rw', 'id': 'vsydnor@upenn.edu'},
#                  {'access': 'rw', 'id': 'rsga@upenn.edu'},
#                  {'access': 'rw', 'id': 'gur@upenn.edu'},
#                  {'access': 'rw', 'id': 'raquel@upenn.edu'},
#                  {'access': 'rw', 'id': 'tymoore@upenn.edu'},
#                  {'access': 'rw', 'id': 'gpretty@upenn.edu'},
#                  {'access': 'rw', 'id': 'jschmitt@upenn.edu'},
#                  {'access': 'rw', 'id': 'scott1@upenn.edu'},
#                  {'access': 'rw', 'id': 'danwolf@pennmedicine.upenn.edu'},
#                  {'access': 'rw', 'id': 'danwolf@upenn.edu'}],
#  'project': '5c8ab803f546b600306d7bdc',
#  'project_has_template': None,
#  'revision': 1189,
#  'satisfies_template': None,
#  'subject': {'age': 693792000,
#              'analyses': None,
#              'code': '014665',
#              'cohort': None,
#              'created': datetime.datetime(2019, 3, 14, 20, 22, 28, 762000, tzinfo=tzutc()),
#              'ethnicity': None,
#              'files': None,
#              'firstname': None,
#              'id': '5c8ab804f546b600306d7be4',
#              'info': None,
#              'info_exists': None,
#              'label': '014665',
#              'lastname': None,
#              'master_code': None,
#              'modified': datetime.datetime(2020, 3, 23, 13, 43, 41, 170000, tzinfo=tzutc()),
#              'notes': None,
#              'parents': {'acquisition': None,
#                          'analysis': None,
#                          'group': 'bbl',
#                          'project': '5c8ab803f546b600306d7bdc',
#                          'session': None,
#                          'subject': None},
#              'permissions': [{'access': 'admin',
#                               'id': 'harshakethineni@flywheel.io'},
#                              {'access': 'admin',
#                               'id': 'kruparel@pennmedicine.upenn.edu'},
#                              {'access': 'admin',
#                               'id': 'kalebfischer@flywheel.io'},
#                              {'access': 'admin', 'id': 'mcieslak@upenn.edu'},
#                              {'access': 'admin', 'id': 'kruparel@upenn.edu'},
#                              {'access': 'rw', 'id': 'roalf@upenn.edu'},
#                              {'access': 'admin', 'id': 'adebimpe@upenn.edu'},
#                              {'access': 'rw', 'id': 'annaxu@upenn.edu'},
#                              {'access': 'admin', 'id': 'ttapera@upenn.edu'},
#                              {'access': 'rw', 'id': 'butellyn@upenn.edu'},
#                              {'access': 'admin', 'id': 'sattertt@upenn.edu'},
#                              {'access': 'rw',
#                               'id': 'sophia.linguiti@upenn.edu'},
#                              {'access': 'rw', 'id': 'pinesa@upenn.edu'},
#                              {'access': 'rw', 'id': 'linguiti@upenn.edu'},
#                              {'access': 'ro',
#                               'id': 'jenna.kantor@pennmedicine.upenn.edu'},
#                              {'access': 'rw', 'id': 'jrkantor@upenn.edu'},
#                              {'access': 'ro', 'id': 'radreview@upenn.edu'},
#                              {'access': 'admin', 'id': 'larsenb@upenn.edu'},
#                              {'access': 'rw', 'id': 'blarsen@upenn.edu'},
#                              {'access': 'ro',
#                               'id': 'radreview@pennbrain.upenn.edu'},
#                              {'access': 'rw', 'id': 'gbaum@upenn.edu'},
#                              {'access': 'rw', 'id': 'zaixucui@upenn.edu'},
#                              {'access': 'rw', 'id': 'diegodav@upenn.edu'},
#                              {'access': 'rw', 'id': 'hxia@upenn.edu'},
#                              {'access': 'rw', 'id': 'moberg@upenn.edu'},
#                              {'access': 'rw', 'id': 'kpiiwaa@upenn.edu'},
#                              {'access': 'rw', 'id': 'krmurtha@upenn.edu'},
#                              {'access': 'rw', 'id': 'apines@upenn.edu'},
#                              {'access': 'rw', 'id': 'vsydnor@upenn.edu'},
#                              {'access': 'rw', 'id': 'sagerush@upenn.edu'},
#                              {'access': 'rw', 'id': 'adrose@upenn.edu'},
#                              {'access': 'rw', 'id': 'rsga@upenn.edu'},
#                              {'access': 'rw', 'id': 'raquel@upenn.edu'},
#                              {'access': 'rw', 'id': 'gur@upenn.edu'},
#                              {'access': 'rw', 'id': 'tymoore@upenn.edu'},
#                              {'access': 'rw', 'id': 'gpretty@upenn.edu'},
#                              {'access': 'rw', 'id': 'jschmitt@upenn.edu'},
#                              {'access': 'rw', 'id': 'scott1@upenn.edu'},
#                              {'access': 'rw',
#                               'id': 'danwolf@pennmedicine.upenn.edu'},
#                              {'access': 'rw', 'id': 'danwolf@upenn.edu'}],
#              'project': '5c8ab803f546b600306d7bdc',
#              'race': None,
#              'revision': 1154,
#              'sex': 'male',
#              'species': None,
#              'strain': None,
#              'tags': None,
#              'type': None},
#  'tags': [],
#  'timestamp': datetime.datetime(2009, 6, 17, 17, 6, 1, tzinfo=tzutc()),
#  'timezone': None,
#  'uid': '12840113745101000100200039979443726413131',
#  'weight': None}

# %%
myconfig = {
    'analysis_type': 'task_acompcor_alff_reho_fcon'
}

myinput = {
    #'antsct': struc,
    'fmriprepdir': fmriprep,
    'designfile': designFile,
    'taskfile': taskfile
    #'img': asl
}
#xcp.run(analysis_label="XCP_SDK_CBF_{}".format(datetime.datetime.now()), destination=eg, inputs=myinput, config=myconfig)

#returns the jobID

# %%
eg.label
# Out:
# '002258'

# %% [markdown]
# Now we run on each session:

# %%
xcp_runs = {}

for i, x in enumerate(sessions):
    ses = fw.get(x.id)

    #struc = get_latest_struct(ses)
    fmriprep = get_latest_fmriprep(ses)
    taskfile1 = get_taskfile(ses)
    
    if  fmriprep and taskfile1 :
        myconfig = {
            'analysis_type': 'task_acompcor_alff_reho_fcon',
            'task_name' :'emotionid'
        }

        myinput = {
            'fmriprepdir': fmriprep,
            'designfile': designFile,
            'taskfile': taskfile1,
        }
        jobid = xcp.run(analysis_label="XCP_SDK_TASK_{}".format(datetime.datetime.now()), destination=ses, inputs=myinput, config=myconfig)
        xcp_runs[ses.label] = jobid
    else:
        xcp_runs[ses.label] = None

# %% [markdown]
# Here are the job IDs:

# %%
import templateflow.api as tf
[str(tf.get('fsLR', space='fsaverage', suffix='sphere', hemi=hemi, density='164k'))
        for hemi in 'LR']
# Out:
# Downloading https://templateflow.s3.amazonaws.com/tpl-fsLR/tpl-fsLR_space-fsaverage_hemi-L_den-164k_sphere.surf.gii
# 3.53kB [00:01, 3.25kB/s]
# Downloading https://templateflow.s3.amazonaws.com/tpl-fsLR/tpl-fsLR_space-fsaverage_hemi-R_den-164k_sphere.surf.gii
# 3.41kB [00:01, 3.15kB/s]
# ['/Users/adebimpe/.cache/templateflow/tpl-fsLR/tpl-fsLR_space-fsaverage_hemi-L_den-164k_sphere.surf.gii',
#  '/Users/adebimpe/.cache/templateflow/tpl-fsLR/tpl-fsLR_space-fsaverage_hemi-R_den-164k_sphere.surf.gii']

# %%
[str(tf.get('fsLR', space='fsaverage', suffix='midthickness', hemi=hemi, density='164k'))
        for hemi in 'LR']
# Out:
# Downloading https://templateflow.s3.amazonaws.com/tpl-fsLR/tpl-fsLR_space-fsaverage_hemi-L_den-164k_midthickness.surf.gii
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-8-e774d1e0a420> in <module>
#       1 [str(tf.get('fsLR', space='fsaverage', suffix='midthickness', hemi=hemi, density='164k'))
# ----> 2         for hemi in 'LR']
#
# <ipython-input-8-e774d1e0a420> in <listcomp>(.0)
#       1 [str(tf.get('fsLR', space='fsaverage', suffix='midthickness', hemi=hemi, density='164k'))
# ----> 2         for hemi in 'LR']
#
# ~/opt/miniconda3/lib/python3.7/site-packages/templateflow/api.py in get(template, **kwargs)
#      65                   if p.is_file() and p.stat().st_size == 0]
#      66     for filepath in s3_missing + dl_missing:
# ---> 67         _s3_get(filepath)
#      68
#      69     not_fetched = [str(p) for p in out_file
#
# ~/opt/miniconda3/lib/python3.7/site-packages/templateflow/api.py in _s3_get(filepath)
#     185         filepath.unlink()
#     186
# --> 187     with filepath.open('wb') as f:
#     188         for data in tqdm(r.iter_content(block_size),
#     189                          total=ceil(total_size // block_size),
#
# ~/opt/miniconda3/lib/python3.7/pathlib.py in open(self, mode, buffering, encoding, errors, newline)
#    1191             self._raise_closed()
#    1192         return io.open(self, mode, buffering, encoding, errors, newline,
# -> 1193                        opener=self._opener)
#    1194
#    1195     def read_bytes(self):
#
# ~/opt/miniconda3/lib/python3.7/pathlib.py in _opener(self, name, flags, mode)
#    1044     def _opener(self, name, flags, mode=0o666):
#    1045         # A stub for the opener argument to built-in open()
# -> 1046         return self._accessor.open(self, flags, mode)
#    1047
#    1048     def _raw_open(self, flags, mode=0o777):
#
# PermissionError: [Errno 13] Permission denied: '/Users/adebimpe/.cache/templateflow/tpl-fsLR/tpl-fsLR_space-fsaverage_hemi-L_den-164k_midthickness.surf.gii'

# %%
from templateflow.api import get as get_template
        
brain_mask = get_template(
            'MNI152NLin2009cAsym', resolution=2, desc='brain', suffix='mask')
# Out:
# Downloading https://templateflow.s3.amazonaws.com/tpl-MNI152NLin2009cAsym/tpl-MNI152NLin2009cAsym_res-02_desc-brain_mask.nii.gz
# 29.0B [00:00, 2.15kB/s]

# %%
str(brain_mask)
# Out:
# '/Users/adebimpe/.cache/templateflow/tpl-MNI152NLin2009cAsym/tpl-MNI152NLin2009cAsym_res-02_desc-brain_mask.nii.gz'

# %% [markdown]
# The reason many didn't run is that 80 is too large a number of volumes for some of the functional ASL scans. Instead, we will redefine the function for ASL and set the floor at 20 and an even number of volumes
